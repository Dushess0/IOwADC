# %% [raw]
# TensorFlow opublikował Speech Commands Datasets. Baza danych zawiera 65 tysięcy jednosekundowych nagrań 30 krótkich słów w języku angielskim, wypowiedzianych przez kilka ttsięcy różnych osób. W trakcie laboratorium zostaną użyte głębokie sieci neuronowe do rozpoznawania tych słów.
#
# Baza nagrań może być pobrana stąd [tutaj](https://www.kaggle.com/c/tensorflow-speech-recognition-challenge).
#
# **Implementacja modelu Speech-to-Text w Python'ie od podstaw**
#
# **Import niezbędnych bibliotek**
#
# W pierwszej kolejności importujemy biblioteki niezbędne do przetwarzania analizowanych danych. LibROSA i SciPy są bibiotekami Python'a używanymi do przetwarzania sygnałów audio.

# %%
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
import warnings

warnings.filterwarnings("ignore")

# %%
os.listdir('./input/')
# Out:
# ['link_to_gcp_credits_form.txt', 'sample_submission.csv', 'train']

# %% [raw]
# **Eksploracja i wizualizacja danych**
#
# Eksploracja i wizualizacja danych pomaga zrozumieć zawartość danych oraz transformację danych w trakcie procesu ich przetwarzania.
#
# **Wizualizacja sygnału audio w dziedzinie czasu**

# %%
train_audio_path = './input/train/audio/'
samples, sample_rate = librosa.load(train_audio_path+'yes/0a7c2a8d_nohash_0.wav', sr = 16000)
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + './input/train/audio/yes/0a7c2a8d_nohash_0.wav')
ax1.set_xlabel('time')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %% [raw]
# **Częstotliwość próbkowania **
#
# Sprawdźmy, jaka jest częstotliwość próbkowania sygnału audio

# %%
ipd.Audio(samples, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(sample_rate)
# Out:
# 16000

# %% [raw]
# **Resampling**
#
# Z informacji zwróconej przez funkcję load z biblioteki LibROSA wynika, że częstotliwośc próbkowania nagrań to 16000 Hz. Wykonamy teraz resamplig sygnału usuwając z sygnału częstotliwości powyżej 8000 Hz. Głowym celem tego zabiegu jest ograniczenie czasu treningu sieci neuronowej. Częstotliwości słyszalne przez ludzkie ucho mieszczą się w przedziale do ok. 22 000 Hz.

# %%
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [raw]
#  A teraz sprawdźmy ile jest w bazie danych nagrań dla każdego polecenia głosowego:

# %%
labels=os.listdir(train_audio_path)

# %%
#dla każdej etykiety z listy kartotek znajdujemy liczbę plików audio w tej kartotece
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#wykres
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

# %%
labels=["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go"]

# %% [raw]
# **Długość nagrań**
#
# A teraz sprawdźmy, jak długie są nagrania poleceń głosowych:

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([1.5000e+01, 3.0000e+01, 4.4000e+01, 1.3800e+02, 1.3600e+02,
#         1.7900e+02, 3.6600e+02, 4.3400e+02, 5.9300e+02, 2.1747e+04]),
#  array([0.418 , 0.4762, 0.5344, 0.5926, 0.6508, 0.709 , 0.7672, 0.8254,
#         0.8836, 0.9418, 1.    ]),
#  <BarContainer object of 10 artists>)

# %% [raw]
# **Preprocessing sygnałów audio**
#
# W efekcie przeprowadzonej eksploracji danych ustaliliśmy, że w przypadku niektórych nagrań ich długość jest mniejsza, niż jedna sekunda oraz, że częstotliwość próbkowania wynosi 16 tys Hz. Spośród wszystkich nagrań do dalszej pracy wybieramy tylko te z komendami zapisanymi w tablicy labels. Wykonujemy resampling nagrań do częstotliwości 8 tys HZ i pozostawiamy tylko nagrania jednosekundowe (złożone z 8000 próbek).
#
#
# Kod realizujący założone kroki preprocessingu:

# %%
train_audio_path = './input/train/audio/'

all_wave = []
all_label = []
for label in labels:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000) : 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# yes
# no
# up
# down
# left
# right
# on
# off
# stop
# go

# %%
#restore session variables
# %store -r  all_wave 
# %store -r all_label

# %% [raw]
# Konwertujemy etykiety tekstowe do kodów całkowitoliczbowych, wymaganych do treningu klasyfikatora:

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %% [raw]
# Zaczyna się magia frameworku keras...
# Konwertujemy całkowitoliczbowe etykiery do jednego wektora:

# %%
from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))

# %% [raw]
# Przerabiamy macierze 2D na 3D ponieważ takiego wejścia spodziewa się sieć, która będzie użyta do rozpoznawania komend głosowych:

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %% [raw]
# **Wybór zbioru treningowego i walidacyjnego**
#
# Użyjemy 80% danych do treningu, a pozostałe 20% do walidacji wytrenowanego modelu:

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)

# %% [raw]
# **Wybór architektury sieci dla problemu rozpozawaia komed głosowych**
#
# Model speech-to-text zostanie zbudowany w oparciu o sieć conv1d. Conv1d to konwolucyjna sieć neuronowa, wykonująca konwolucję tylko w jedym wymiarze.

# %% [raw]
# **Budowa modelu**
#
# Budujemy model korzystając z API frameworku Keras.

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
import tensorflow as tf
from tensorflow.compat.v1.keras import backend as K
K.clear_session()
config = tf.compat.v1.ConfigProto( device_count = {'GPU': 1 , 'CPU': 48} , log_device_placement=True )
sess = tf.compat.v1.Session(config=config) 
K.set_session(sess)

inputs = Input(shape=(8000,1))

#First Conv1D layer
conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Second Conv1D layer
conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Third Conv1D layer
conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Fourth Conv1D layer
conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Flatten layer
conv = Flatten()(conv)

#Dense Layer 1
conv = Dense(256, activation='relu')(conv)
conv = Dropout(0.3)(conv)

#Dense Layer 2
conv = Dense(128, activation='relu')(conv)
conv = Dropout(0.3)(conv)

outputs = Dense(len(labels), activation='softmax')(conv)

model = Model(inputs, outputs)
model.summary()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce GTX 1060 3GB, pci bus id: 0000:03:00.0, compute capability: 6.1
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8000, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 7988, 8)           112
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 2662, 8)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 2662, 8)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2652, 16)          1424
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 884, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 884, 16)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 876, 32)           4640
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 292, 32)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 292, 32)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 286, 64)           14400
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 95, 64)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 95, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 6080)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1556736
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,611,498
# Trainable params: 1,611,498
# Non-trainable params: 0
# _________________________________________________________________

# %% [raw]
# Definiujemy "loss function" w oparciu o "categorical cross-entropy" - wybór odpowiedni dla problemu klasyfikacji wieloklasowej:

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [raw]
# "Early stopping" i "model checkpoints" to callback'i użyte w celu zatrzymania treningu sieci neuronowej w odpowiednim momencie (zanim zacznie się przetrenowanie) i w celu zapisania najlepszego uzyskanego modelu uzyskanego po każdej z epok treingu:

# %%
metric = 'val_accuracy'
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %% [raw]
# Trening i testowaie na zbiorze walidacyjnym:

# %%
history=model.fit(x_tr, y_tr ,epochs=20, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
# Out:
# Epoch 1/20
# 533/533 [==============================] - 10s 19ms/step - loss: 0.4094 - accuracy: 0.8573 - val_loss: 0.5155 - val_accuracy: 0.8285
#
# Epoch 00001: val_accuracy improved from -inf to 0.82852, saving model to best_model.hdf5
# Epoch 2/20
# 533/533 [==============================] - 9s 18ms/step - loss: 0.3910 - accuracy: 0.8640 - val_loss: 0.5206 - val_accuracy: 0.8318
#
# Epoch 00002: val_accuracy improved from 0.82852 to 0.83181, saving model to best_model.hdf5
# Epoch 3/20
# 533/533 [==============================] - 9s 18ms/step - loss: 0.3844 - accuracy: 0.8655 - val_loss: 0.4746 - val_accuracy: 0.8449
#
# Epoch 00003: val_accuracy improved from 0.83181 to 0.84494, saving model to best_model.hdf5
# Epoch 4/20
# 533/533 [==============================] - 10s 18ms/step - loss: 0.3822 - accuracy: 0.8718 - val_loss: 0.4936 - val_accuracy: 0.8370
#
# Epoch 00004: val_accuracy did not improve from 0.84494
# Epoch 5/20
# 533/533 [==============================] - 10s 18ms/step - loss: 0.3842 - accuracy: 0.8695 - val_loss: 0.4795 - val_accuracy: 0.8445
#
# Epoch 00005: val_accuracy did not improve from 0.84494
# Epoch 6/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3538 - accuracy: 0.8757 - val_loss: 0.4976 - val_accuracy: 0.8412
#
# Epoch 00006: val_accuracy did not improve from 0.84494
# Epoch 7/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3683 - accuracy: 0.8718 - val_loss: 0.4747 - val_accuracy: 0.8447
#
# Epoch 00007: val_accuracy did not improve from 0.84494
# Epoch 8/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3635 - accuracy: 0.8741 - val_loss: 0.5450 - val_accuracy: 0.8238
#
# Epoch 00008: val_accuracy did not improve from 0.84494
# Epoch 9/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3664 - accuracy: 0.8737 - val_loss: 0.4724 - val_accuracy: 0.8513
#
# Epoch 00009: val_accuracy improved from 0.84494 to 0.85128, saving model to best_model.hdf5
# Epoch 10/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3295 - accuracy: 0.8860 - val_loss: 0.5161 - val_accuracy: 0.8290
#
# Epoch 00010: val_accuracy did not improve from 0.85128
# Epoch 11/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3465 - accuracy: 0.8815 - val_loss: 0.5012 - val_accuracy: 0.8335
#
# Epoch 00011: val_accuracy did not improve from 0.85128
# Epoch 12/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3302 - accuracy: 0.8839 - val_loss: 0.5274 - val_accuracy: 0.8304
#
# Epoch 00012: val_accuracy did not improve from 0.85128
# Epoch 13/20
# 533/533 [==============================] - 9s 18ms/step - loss: 0.3331 - accuracy: 0.8875 - val_loss: 0.4600 - val_accuracy: 0.8478
#
# Epoch 00013: val_accuracy did not improve from 0.85128
# Epoch 14/20
# 533/533 [==============================] - 9s 18ms/step - loss: 0.3194 - accuracy: 0.8886 - val_loss: 0.4862 - val_accuracy: 0.8395
#
# Epoch 00014: val_accuracy did not improve from 0.85128
# Epoch 15/20
# 533/533 [==============================] - 9s 17ms/step - loss: 0.3164 - accuracy: 0.8892 - val_loss: 0.4694 - val_accuracy: 0.8442
#
# Epoch 00015: val_accuracy did not improve from 0.85128
# Epoch 16/20
# 533/533 [==============================] - 10s 18ms/step - loss: 0.3139 - accuracy: 0.8918 - val_loss: 0.5050 - val_accuracy: 0.8386
#
# Epoch 00016: val_accuracy did not improve from 0.85128
# Epoch 17/20
# 533/533 [==============================] - 9s 18ms/step - loss: 0.3098 - accuracy: 0.8949 - val_loss: 0.4704 - val_accuracy: 0.8522
#
# Epoch 00017: val_accuracy improved from 0.85128 to 0.85222, saving model to best_model.hdf5
# Epoch 18/20
# 533/533 [==============================] - 9s 18ms/step - loss: 0.3069 - accuracy: 0.8946 - val_loss: 0.4937 - val_accuracy: 0.8433
#
# Epoch 00018: val_accuracy did not improve from 0.85222
# Epoch 19/20
# 533/533 [==============================] - 9s 18ms/step - loss: 0.2976 - accuracy: 0.8985 - val_loss: 0.4667 - val_accuracy: 0.8564
#
# Epoch 00019: val_accuracy improved from 0.85222 to 0.85644, saving model to best_model.hdf5
# Epoch 20/20
# 533/533 [==============================] - 10s 18ms/step - loss: 0.3046 - accuracy: 0.8960 - val_loss: 0.4726 - val_accuracy: 0.8506
#
# Epoch 00020: val_accuracy did not improve from 0.85644

# %% [raw]
# **Wykres diagnostyczny**
#
# Wizualizacja pomaga nam zrozumieć, jak działa sieć na danych treningiwych, a jak na walidacyjnych:

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [raw]
# **Ładujemy najlepszy zapamiętany model**

# %%
from keras.models import load_model
model=load_model('best_model.hdf5')

# %% [raw]
# Definiujemy funkcję, która znajduje wyraz odpowiadający sygnałowi audio::

# %%
def predict(audio):
    prob=model.predict(audio.reshape(-1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %% [raw]
# **Predykcja**
# Sprawdzamy działanie wytrenowanej sieci na zbiorze walidacyjnym (poniższy skrypt można uruchamiać wielokrotnie):

# %%
import random
index=random.randint(0,len(x_val)-1)
samples=x_val[index].ravel()
print("Audio:",classes[np.argmax(y_val[index])])
ipd.Audio(samples, rate=8000)
# Out:
# Audio: on
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Text:",predict(samples))
# Out:
# Text: on

# %% [raw]
# Poniższy skrypt prosi użytkownika o nagranie komendy głosowej. Proszę nagrać jedną z komend rozpoznawanych przez wytrenowaną sieć:

# %%
import sounddevice as sd
import soundfile as sf

samplerate = 16000  
duration = 1 # seconds
filename = 'input/stop.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)
# Out:
# start
# end

# %% [raw]
# Wczytajmy zapisany plik audio i sprawdźmy, jak radzi sobie z nim wytrenowana sieć:

# %%
os.listdir('./input')
# Out:
# ['link_to_gcp_credits_form.txt', 'sample_submission.csv', 'stop.wav', 'train']

# %%
filepath='./input'

# %%
#reading the voice commands
samples, sample_rate = librosa.load(filepath + '/' + 'stop.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#converting voice commands to text
predict(samples)
# Out:
# 'go'

# %%
#save session variables

# %store  all_wave 
# %store  all_label
# Out:
# Stored 'all_wave' (ndarray)
# Stored 'all_label' (list)

# %%
#restore session variables
# %store -r  all_wave 
# %store -r all_label

# %% [raw]
# Gratulacje! A teraz proszę sprawdzić skuteczność działania sieci na całym zbiorze walidacyjnym...
